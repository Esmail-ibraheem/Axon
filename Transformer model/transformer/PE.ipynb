# %% [markdown]
# ### Positional Encoding sin and cosine matrices

# %%
import numpy as np
import matplotlib.pyplot as plt

def getPositionEncoding(seq_len, d, n=10000):
    P = np.zeros((seq_len, d))
    for k in range(seq_len):
        for i in np.arange(int(d/2)):
            denominator = np.power(n, 2*i/d)
            P[k, 2*i] = np.sin(k/denominator)
            P[k, 2*i+1] = np.cos(k/denominator)
    return P

P = getPositionEncoding(seq_len=83, d=512, n=100)
print(P)
# Out:
# [[ 0.          1.          0.         ...  1.          0.
#    1.        ]
#  [ 0.84147098  0.54030231  0.8317052  ...  0.99994627  0.01018134
#    0.99994817]
#  [ 0.90929743 -0.41614684  0.92355454 ...  0.99978509  0.02036163
#    0.99979268]
#  ...
#  [-0.99388865 -0.11038724 -0.03392828 ...  0.67538747  0.72739724
#    0.68621662]
#  [-0.62988799  0.77668598 -0.85006394 ...  0.66770653  0.73434615
#    0.67877517]
#  [ 0.31322878  0.9496777  -0.91001245 ...  0.65995384  0.74121893
#    0.67126336]]

# %% [markdown]
# ### Visualize the sin and cosine

# %%
def plotSinusoid(k, d=512, n=10000):
    x = np.arange(0, 100, 1)
    denominator = np.power(n, 2*x/d)
    y = np.sin(k/denominator)
    plt.plot(x, y)
    plt.title('k = ' + str(k))

fig = plt.figure(figsize=(15, 4))    
for i in range(4):
    plt.subplot(141 + i)
    plotSinusoid(i*4)

# %%
P = getPositionEncoding(seq_len=100, d=512, n=10000)
cax = plt.matshow(P)
plt.gcf().colorbar(cax)
